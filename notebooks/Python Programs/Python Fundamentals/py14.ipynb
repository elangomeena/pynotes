# %%
result = 10 + 5 * 2 ** 2
print(result)  # Output: 30
# Out:
# 30

# %%
age = 20

if age >= 18:
    print("Eligible to vote")
# Out:
# Eligible to vote

# %%
temperature = 15

if temperature > 25:
    print("It's warm outside")
else:
    print("It's cold outside")
# Out:
# It's cold outside
