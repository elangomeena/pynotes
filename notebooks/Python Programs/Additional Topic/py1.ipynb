# %%
result = 10 + 5 * 2
print(result)  # 20, not 30
# Out:
# 20

# %%
result = 100 / 10 / 2
print(result)  # 5.0
# Out:
# 5.0

# %%
result = (10 + 5) * 2
print(result)  # 30
# Out:
# 30

# %%
result = 2 + 3 * 4 - 5
print(result)  # 9
# Out:
# 9
