# %%
result = 10 > 5 and 5 > 2
print(result)  # True
# Out:
# True

# %%
result = True or False and False
print(result)  # True
# Out:
# True

# %%
x = y = 10 + 5
print(x, y)  # 15 15
# Out:
# 15 15

# %%
result = 2 ** 3 ** 2
print(result)  # 512
# Out:
# 512
