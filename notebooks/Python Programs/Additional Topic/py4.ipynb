# %%
total = 100
def calculate_sum():
    pass

class User:
    pass

# %%
valid_name = 10
_invalid = 20
# 1value = 30  # Invalid

# %%
value = 10
Value = 20

print(value)  # 10
print(Value)  # 20
# Out:
# 10
# 20

# %%
# 2data = 100      # Starts with digit (Invalid)
# class = 10       # Keyword (Invalid)
# my-name = 5      # Special character (Invalid)
