# %%
class Person:
    pass

p1 = Person()
print(p1)

# %%
class Person:
    name = "Alice"
    age = 25

p = Person()
print(p.name)
print(p.age)
# Out:
# Alice
# 25

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

p = Person("Bob", 30)
print(p.name, p.age)
# Out:
# Bob 30
