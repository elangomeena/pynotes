# %%
import time

def api_request():
    print("Request sent")
    time.sleep(1)

for _ in range(5):
    api_request()
# Out:
# Request sent
# Request sent
# Request sent
# Request sent
# Request sent

# %%
import time

print("Task started...")
time.sleep(3)
print("Task completed.")
# Out:
# Task started...
# Task completed.

# %%
import asyncio

async def task():
    print("Waiting...")
    await asyncio.sleep(2)
    print("Done")

await task()
#asyncio.run(task())
# Out:
# Waiting...
# Done

# %%
import time

def process_batches():
    for batch in range(1, 4):
        print(f"Processing batch {batch}")
        time.sleep(2)

process_batches()
# Out:
# Processing batch 1
# Processing batch 2
# Processing batch 3
