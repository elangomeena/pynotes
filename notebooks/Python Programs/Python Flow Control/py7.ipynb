# %%
count = 1

while count <= 5:
    print(count)
    count += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
number = 5

while number > 0:
    print(number)
    number -= 1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
user_input = ""

while user_input != "exit":
    user_input = input("Type 'exit' to stop: ")
# Out:
# Type 'exit' to stop:  hi
# Type 'exit' to stop:  exit
