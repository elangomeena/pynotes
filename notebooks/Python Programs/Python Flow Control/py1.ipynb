# %%
score = 85

if score >= 90:
    print("Grade: A")
elif score >= 75:
    print("Grade: B")
elif score >= 60:
    print("Grade: C")
else:
    print("Grade: D")
# Out:
# Grade: B

# %%
username = "admin"
password = "1234"

if username == "admin":
    if password == "1234":
        print("Access granted")
    else:
        print("Incorrect password")
# Out:
# Access granted

# %%
age = 25
is_verified = True

if age > 18 and is_verified:
    print("User can proceed")
# Out:
# User can proceed
