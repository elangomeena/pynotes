# %%
score = 85

if score > 90:
    print("Excellent")
elif score > 80:
    pass
else:
    print("Needs Improvement")

# %%
for i in range(5):
    if i == 2:
        pass      # Does nothing
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
try:
    risky_operation()
except Exception:
    pass
