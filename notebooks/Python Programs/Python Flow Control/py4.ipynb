# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(2, 10, 2):
    print(i)
# Out:
# 2
# 4
# 6
# 8

# %%
word = "Python"

for char in word:
    print(char)
# Out:
# P
# y
# t
# h
# o
# n
