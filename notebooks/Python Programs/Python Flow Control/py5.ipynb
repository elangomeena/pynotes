# %%
languages = ["Python", "Java", "C++"]

for index, lang in enumerate(languages):
    print(index, lang)
# Out:
# 0 Python
# 1 Java
# 2 C++

# %%
for i in range(3):
    for j in range(2):
        print(f"i={i}, j={j}")
# Out:
# i=0, j=0
# i=0, j=1
# i=1, j=0
# i=1, j=1
# i=2, j=0
# i=2, j=1

# %%
for number in range(1, 10):
    if number == 5:
        break
    print(number)
# Out:
# 1
# 2
# 3
# 4
