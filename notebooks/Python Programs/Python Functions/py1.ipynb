# %%
def greet():
    print("Hello, Python!")

greet()
# Out:
# Hello, Python!

# %%
def greet_user(name):
    print(f"Hello, {name}!")

greet_user("Alice")
# Out:
# Hello, Alice!

# %%
def add(a, b):
    return a + b

result = add(5, 3)
print(result)  # Output: 8
# Out:
# 8
