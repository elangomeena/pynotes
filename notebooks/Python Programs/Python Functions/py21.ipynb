# %%
def main():
    print("Program started")

main()
# Out:
# Program started

# %%
def main():
    print("Main function executed")

if __name__ == "__main__":
    main()
# Out:
# Main function executed

# %%
print(__name__)
# Out:
# __main__
