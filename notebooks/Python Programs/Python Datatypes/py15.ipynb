# %%
fruits = {"apple", "banana"}

fruits.add("orange")
print(fruits)
# Out:
# {'apple', 'banana', 'orange'}

# %%
colors = {"red", "green"}
colors.update(["blue", "yellow"])

print(colors)
# Out:
# {'green', 'red', 'blue', 'yellow'}

# %%
numbers = {10, 20, 30, 40}

numbers.remove(20)
numbers.discard(50)  # No error if element doesn't exist

print(numbers)
# Out:
# {40, 10, 30}
