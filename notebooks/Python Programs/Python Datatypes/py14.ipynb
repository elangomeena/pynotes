# %%
word = "Code"

for char in word:
    print(char)
# Out:
# C
# o
# d
# e

# %%
empty_set = set()
unique_numbers = {1, 2, 3, 4}
mixed_set = {1, "Python", 3.5, True}

print(empty_set)
print(unique_numbers)
print(mixed_set)
# Out:
# set()
# {1, 2, 3, 4}
# {1, 3.5, 'Python'}

# %%
numbers = {1, 2, 2, 3, 3, 4}
print(numbers)  # Output: {1, 2, 3, 4}
# Out:
# {1, 2, 3, 4}
