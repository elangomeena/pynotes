# %%
single_quote = 'Hello'
double_quote = "World"
multi_line = """This is
a multi-line
string"""

print(single_quote)
print(double_quote)
print(multi_line)
# Out:
# Hello
# World
# This is
# a multi-line
# string

# %%
text = "Python"

print(text[0])    # P
print(text[-1])   # n
# Out:
# P
# n

# %%
word = "Programming"

print(word[0:6])   # Output: Progra
print(word[:4])    # Output: Prog
print(word[4:])    # Output: ramming
# Out:
# Progra
# Prog
# ramming
